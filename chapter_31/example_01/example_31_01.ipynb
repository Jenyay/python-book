# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(0, np.pi * 3, 0.01)
y = np.sin(x) * np.cos(2 * x)
plt.plot(x, y)

# %%
data = pd.read_csv('space_missions.csv', usecols=[0, 2, 4, 5, 7, 8])
data
# Out:
#         Company        Date            Rocket              Mission  Price  \
# 0     RVSN USSR  1957-10-04    Sputnik 8K71PS            Sputnik-1    NaN
# 1     RVSN USSR  1957-11-03    Sputnik 8K71PS            Sputnik-2    NaN
# 2       US Navy  1957-12-06          Vanguard         Vanguard TV3    NaN
# 3          AMBA  1958-02-01            Juno I           Explorer 1    NaN
# 4       US Navy  1958-02-05          Vanguard       Vanguard TV3BU    NaN
# ...         ...         ...               ...                  ...    ...
# 4625     SpaceX  2022-07-22  Falcon 9 Block 5   Starlink Group 3-2     67
# 4626       CASC  2022-07-24     Long March 5B              Wentian    NaN
# 4627     SpaceX  2022-07-24  Falcon 9 Block 5  Starlink Group 4-25     67
# 4628  CAS Space  2022-07-27        Zhongke-1A          Demo Flight    NaN
# 4629       CASC  2022-07-29     Long March 2D   Yaogan 35 Group 03  29.75
#
#      MissionStatus
# 0          Success
# 1          Success
# 2          Failure
# 3          Success
# 4          Failure
# ...            ...
# 4625       Success
# 4626       Success
# 4627       Success
# 4628       Success
# 4629       Success
#
# [4630 rows x 6 columns]
